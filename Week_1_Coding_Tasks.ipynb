# %% [markdown]
# ## Week 1 Coding Tasks
#
# A dataset containing information on US hospitals is contained in the data folder in the file `Hospitals.csv`. This datset was downloaded from [the Homeland Infrastructure Foundation-Level Data (HIFLD) database](https://hifld-geoplatform.opendata.arcgis.com/datasets/hospitals/explore).

# %% [markdown]
# 1. Read this dataset into a DataFrame named `hospitals`.

# %%
import pandas as pd

# %%
hospitals = pd.read_csv('../data/Hospitals.csv')

# %% [markdown]
# 2. Look at the first few rows and then look at the last few. What do you notice?

# %%
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
# 2 -1.315620e+07  4.031978e+06         3  11190023
# 3 -1.317190e+07  4.041752e+06         4  17090028
# 4 -1.313208e+07  4.037270e+06         5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  NOT AVAILABLE
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  NOT AVAILABLE
#
#    ...             VAL_DATE                           WEBSITE       STATE_ID  \
# 0  ...  2014/02/10 00:00:00      http://www.hanfordhealth.com  NOT AVAILABLE
# 1  ...  2014/02/10 00:00:00  http://www.losrobleshospital.com  NOT AVAILABLE
# 2  ...  2014/02/10 00:00:00             http://www.elalax.com  NOT AVAILABLE
# 3  ...  2014/02/10 00:00:00         http://sch-hollywood.com/  NOT AVAILABLE
# 4  ...  2014/02/10 00:00:00      http://www.khbaldwinpark.com  NOT AVAILABLE
#
#                                     ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                              NOT AVAILABLE       6  PROPRIETARY      -999
# 1                              NOT AVAILABLE       6  PROPRIETARY      -999
# 2                              NOT AVAILABLE       6  PROPRIETARY      -999
# 3  HOLLYWOOD COMMUNITY HOSPITAL OF HOLLYWOOD       6  PROPRIETARY      -999
# 4                              NOT AVAILABLE       6  PROPRIETARY      -999
#
#    BEDS         TRAUMA  HELIPAD
# 0    49  NOT AVAILABLE        N
# 1    62  NOT AVAILABLE        N
# 2   127  NOT AVAILABLE        N
# 3   100  NOT AVAILABLE        N
# 4    95  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
hospitals.head()
# Out:
#               X             Y  OBJECTID        ID  \
# 0 -1.331889e+07  4.346975e+06         1   5793230
# 1 -1.322651e+07  4.049626e+06         2  53391362
# 2 -1.315620e+07  4.031978e+06         3  11190023
# 3 -1.317190e+07  4.041752e+06         4  17090028
# 4 -1.313208e+07  4.037270e+06         5  23691706
#
#                                                 NAME  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                  EAST LOS ANGELES DOCTORS HOSPITAL
# 3          SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                      KINDRED HOSPITAL BALDWIN PARK
#
#                      ADDRESS             CITY STATE    ZIP           ZIP4  \
# 0    1025 NORTH DOUTY STREET          HANFORD    CA  93230  NOT AVAILABLE
# 1             150 VIA MERIDA  WESTLAKE VILAGE    CA  91362  NOT AVAILABLE
# 2    4060 WHITTIER BOULEVARD      LOS ANGELES    CA  90023  NOT AVAILABLE
# 3     6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  90028  NOT AVAILABLE
# 4  14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  91706  NOT AVAILABLE
#
#    ...             VAL_DATE                           WEBSITE       STATE_ID  \
# 0  ...  2014/02/10 00:00:00      http://www.hanfordhealth.com  NOT AVAILABLE
# 1  ...  2014/02/10 00:00:00  http://www.losrobleshospital.com  NOT AVAILABLE
# 2  ...  2014/02/10 00:00:00             http://www.elalax.com  NOT AVAILABLE
# 3  ...  2014/02/10 00:00:00         http://sch-hollywood.com/  NOT AVAILABLE
# 4  ...  2014/02/10 00:00:00      http://www.khbaldwinpark.com  NOT AVAILABLE
#
#                                     ALT_NAME ST_FIPS        OWNER TTL_STAFF  \
# 0                              NOT AVAILABLE       6  PROPRIETARY      -999
# 1                              NOT AVAILABLE       6  PROPRIETARY      -999
# 2                              NOT AVAILABLE       6  PROPRIETARY      -999
# 3  HOLLYWOOD COMMUNITY HOSPITAL OF HOLLYWOOD       6  PROPRIETARY      -999
# 4                              NOT AVAILABLE       6  PROPRIETARY      -999
#
#    BEDS         TRAUMA  HELIPAD
# 0    49  NOT AVAILABLE        N
# 1    62  NOT AVAILABLE        N
# 2   127  NOT AVAILABLE        N
# 3   100  NOT AVAILABLE        N
# 4    95  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
hospitals.tail()
# Out:
#                  X             Y  OBJECTID         ID  \
# 7591 -8.566905e+06  4.728815e+06      7607  183520904
# 7592 -1.219624e+07  3.676931e+06      7608  192185607
# 7593 -8.084677e+06  5.094112e+06      7609  196706457
# 7594 -8.522423e+06  4.718512e+06      7610  191021401
# 7595 -1.244921e+07  4.976468e+06      7611  196784108
#
#                                                NAME  \
# 7591  ADVENTIST HEALTHCARE WHITE OAK MEDICAL CENTER
# 7592      COPPER QUEEN DOUGLAS EMERGENCY DEPARTMENT
# 7593                      WHITING FORENSIC HOSPITAL
# 7594             J KENT MCNEW FAMILY MEDICAL CENTER
# 7595                  UNIVERSITY ORTHOPAEDIC CENTER
#
#                          ADDRESS            CITY STATE    ZIP           ZIP4  \
# 7591           11890 HEALING WAY   SILVER SPRING    MD  20904  NOT AVAILABLE
# 7592           100 E. 5TH STREET         DOUGLAS    AZ  85607  NOT AVAILABLE
# 7593                70 OBRIEN DR      MIDDLETOWN    CT   6457           3945
# 7594  175 HARRY S TRUMAN PARKWAY       ANNAPOLIS    MD  21401  NOT AVAILABLE
# 7595              590 WAKARA WAY  SALT LAKE CITY    UT  84108  NOT AVAILABLE
#
#       ...             VAL_DATE  \
# 7591  ...  2020/05/05 00:00:00
# 7592  ...  2020/05/05 00:00:00
# 7593  ...  2020/05/08 00:00:00
# 7594  ...  2020/05/05 00:00:00
# 7595  ...  2020/05/05 00:00:00
#
#                                                 WEBSITE       STATE_ID  \
# 7591  https://www.adventisthealthcare.com/locations/...  NOT AVAILABLE
# 7592  https://cqch.org/cqch-clinics/copper-queen-dou...  NOT AVAILABLE
# 7593  https://portal.ct.gov/dmhas/wfh/whiting-forens...  NOT AVAILABLE
# 7594  https://aahs.org/locations/j--kent-mcnew-famil...  NOT AVAILABLE
# 7595          https://healthcare.utah.edu/orthopaedics/  NOT AVAILABLE
#
#            ALT_NAME ST_FIPS               OWNER TTL_STAFF  BEDS  \
# 7591  NOT AVAILABLE      24          NON-PROFIT      -999   178
# 7592  NOT AVAILABLE       4          NON-PROFIT      -999  -999
# 7593  NOT AVAILABLE       9  GOVERNMENT - STATE      -999   229
# 7594  NOT AVAILABLE      24          NON-PROFIT      -999  -999
# 7595  NOT AVAILABLE      49  GOVERNMENT - STATE      -999  -999
#
#              TRAUMA  HELIPAD
# 7591  NOT AVAILABLE        N
# 7592       LEVEL IV        N
# 7593  NOT AVAILABLE        N
# 7594  NOT AVAILABLE        N
# 7595  NOT AVAILABLE        N
#
# [5 rows x 34 columns]

# %%
hospitals.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'ID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP',
#        'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY',
#        'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE',
#        'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE',
#        'WEBSITE', 'STATE_ID', 'ALT_NAME', 'ST_FIPS', 'OWNER', 'TTL_STAFF',
#        'BEDS', 'TRAUMA', 'HELIPAD'],
#       dtype='object')

# %% [markdown]
# 3. How many rows and columns does this DataFrame have?

# %%
hospitals.shape
# Out:
# (7596, 34)

# %% [markdown]
# 4. We don't need all of the columns. Slice the dataframe down so that it only contains the following columns: 'NAME', 'ADDRESS', 'CITY', 'STATE', 'TYPE',  'POPULATION', 'COUNTY', 'COUNTYFIPS', 'NAICS_DESC', 'BEDS'

# %%
hospitals = hospitals[['NAME', 'ADDRESS', 'CITY', 'STATE',
           'TYPE',  'POPULATION', 'COUNTY', 'COUNTYFIPS',
           'NAICS_DESC', 'BEDS']]

hospitals
# Out:
#                                                    NAME  \
# 0                       CENTRAL VALLEY GENERAL HOSPITAL
# 1     LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...
# 2                     EAST LOS ANGELES DOCTORS HOSPITAL
# 3             SOUTHERN CALIFORNIA HOSPITAL AT HOLLYWOOD
# 4                         KINDRED HOSPITAL BALDWIN PARK
# ...                                                 ...
# 7591      ADVENTIST HEALTHCARE WHITE OAK MEDICAL CENTER
# 7592          COPPER QUEEN DOUGLAS EMERGENCY DEPARTMENT
# 7593                          WHITING FORENSIC HOSPITAL
# 7594                 J KENT MCNEW FAMILY MEDICAL CENTER
# 7595                      UNIVERSITY ORTHOPAEDIC CENTER
#
#                          ADDRESS             CITY STATE                TYPE  \
# 0        1025 NORTH DOUTY STREET          HANFORD    CA  GENERAL ACUTE CARE
# 1                 150 VIA MERIDA  WESTLAKE VILAGE    CA  GENERAL ACUTE CARE
# 2        4060 WHITTIER BOULEVARD      LOS ANGELES    CA  GENERAL ACUTE CARE
# 3         6245 DE LONGPRE AVENUE        HOLLYWOOD    CA  GENERAL ACUTE CARE
# 4      14148 FRANCISQUITO AVENUE     BALDWIN PARK    CA  GENERAL ACUTE CARE
# ...                          ...              ...   ...                 ...
# 7591           11890 HEALING WAY    SILVER SPRING    MD  GENERAL ACUTE CARE
# 7592           100 E. 5TH STREET          DOUGLAS    AZ  GENERAL ACUTE CARE
# 7593                70 OBRIEN DR       MIDDLETOWN    CT         PSYCHIATRIC
# 7594  175 HARRY S TRUMAN PARKWAY        ANNAPOLIS    MD         PSYCHIATRIC
# 7595              590 WAKARA WAY   SALT LAKE CITY    UT  GENERAL ACUTE CARE
#
#       POPULATION        COUNTY COUNTYFIPS  \
# 0             49         KINGS      06031
# 1             62       VENTURA      06111
# 2            127   LOS ANGELES      06037
# 3            100   LOS ANGELES      06037
# 4             95   LOS ANGELES      06037
# ...          ...           ...        ...
# 7591         178    MONTGOMERY      24031
# 7592        -999       COCHISE      04003
# 7593         229     MIDDLESEX      09007
# 7594        -999  ANNE ARUNDEL      24003
# 7595        -999     SALT LAKE      49035
#
#                                      NAICS_DESC  BEDS
# 0        GENERAL MEDICAL AND SURGICAL HOSPITALS    49
# 1        GENERAL MEDICAL AND SURGICAL HOSPITALS    62
# 2        GENERAL MEDICAL AND SURGICAL HOSPITALS   127
# 3        GENERAL MEDICAL AND SURGICAL HOSPITALS   100
# 4        GENERAL MEDICAL AND SURGICAL HOSPITALS    95
# ...                                         ...   ...
# 7591     GENERAL MEDICAL AND SURGICAL HOSPITALS   178
# 7592     GENERAL MEDICAL AND SURGICAL HOSPITALS  -999
# 7593  PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS   229
# 7594  PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS  -999
# 7595     GENERAL MEDICAL AND SURGICAL HOSPITALS  -999
#
# [7596 rows x 10 columns]

# %% [markdown]
# 5. What are the different hospital types (contained in the `TYPE` column)? Which is the most common?

# %%
hospitals['TYPE'].value_counts()
# Out:
# GENERAL ACUTE CARE    4481
# CRITICAL ACCESS       1027
# PSYCHIATRIC            759
# LONG TERM CARE         431
# REHABILITATION         378
# MILITARY               216
# SPECIAL                145
# CHILDREN               130
# WOMEN                   20
# CHRONIC DISEASE          9
# Name: TYPE, dtype: int64

# %% [markdown]
# 6. Find all hospitals in Nashville, Tennessee. Take a look at the BEDS column. What do you notice? Why do you think this is?

# %%
hospitals.head(2)
# Out:
#                                                 NAME                  ADDRESS  \
# 0                    CENTRAL VALLEY GENERAL HOSPITAL  1025 NORTH DOUTY STREET
# 1  LOS ROBLES HOSPITAL & MEDICAL CENTER - EAST CA...           150 VIA MERIDA
#
#               CITY STATE                TYPE  POPULATION   COUNTY COUNTYFIPS  \
# 0          HANFORD    CA  GENERAL ACUTE CARE          49    KINGS      06031
# 1  WESTLAKE VILAGE    CA  GENERAL ACUTE CARE          62  VENTURA      06111
#
#                                NAICS_DESC  BEDS
# 0  GENERAL MEDICAL AND SURGICAL HOSPITALS    49
# 1  GENERAL MEDICAL AND SURGICAL HOSPITALS    62

# %%
nash_hospitals = hospitals.loc[hospitals['CITY'] == 'NASHVILLE']
nash_hospitals
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 2083                            SGMC BERRIEN CAMPUS
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 3780                     WASHINGTON COUNTY HOSPITAL
# 4253                       HOWARD MEMORIAL HOSPITAL
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 2083         1221 E MCPHERSON AVENUE  NASHVILLE    GA  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# 3485  1412 COUNTY HOSPITAL ROAD, B-1  NASHVILLE    TN      LONG TERM CARE
# 3780          705 SOUTH GRAND AVENUE  NASHVILLE    IL     CRITICAL ACCESS
# 4253              130 MEDICAL CIRCLE  NASHVILLE    AR  GENERAL ACUTE CARE
# 5429              2221 MURPHY AVENUE  NASHVILLE    TN               WOMEN
# 5433              1818 ALBION STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6289              2000 CHURCH STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6293             2201 CHILDREN'S WAY  NASHVILLE    TN      REHABILITATION
# 6661                 1310 24TH AVE S  NASHVILLE    TN            MILITARY
# 6774              2011 MURPHY AVENUE  NASHVILLE    TN  GENERAL ACUTE CARE
# 6777               4220 HARDING ROAD  NASHVILLE    TN  GENERAL ACUTE CARE
# 6786                391 WALLACE ROAD  NASHVILLE    TN  GENERAL ACUTE CARE
# 6808           2300 PATTERSON STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6813       1211 MEDICAL CENTER DRIVE  NASHVILLE    TN  GENERAL ACUTE CARE
#
#       POPULATION      COUNTY COUNTYFIPS  \
# 545          213    DAVIDSON      47037
# 2083          63     BERRIEN      13019
# 3449          70    DAVIDSON      47037
# 3485          60    DAVIDSON      47037
# 3780          50  WASHINGTON      17189
# 4253          20      HOWARD      05061
# 5429        -999    DAVIDSON      47037
# 5433         150    DAVIDSON      47037
# 6289         683    DAVIDSON      47037
# 6293          80    DAVIDSON      47037
# 6661         493    DAVIDSON      47037
# 6774          23    DAVIDSON      47037
# 6777         541    DAVIDSON      47037
# 6786         126    DAVIDSON      47037
# 6808         733    DAVIDSON      47037
# 6813        1091    DAVIDSON      47037
#
#                                              NAICS_DESC  BEDS
# 545              GENERAL MEDICAL AND SURGICAL HOSPITALS   213
# 2083             GENERAL MEDICAL AND SURGICAL HOSPITALS    63
# 3449  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...    70
# 3485  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...    60
# 3780             GENERAL MEDICAL AND SURGICAL HOSPITALS    50
# 4253             GENERAL MEDICAL AND SURGICAL HOSPITALS    20
# 5429  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...  -999
# 5433             GENERAL MEDICAL AND SURGICAL HOSPITALS   150
# 6289             GENERAL MEDICAL AND SURGICAL HOSPITALS   683
# 6293  REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, D...    80
# 6661             GENERAL MEDICAL AND SURGICAL HOSPITALS   493
# 6774             GENERAL MEDICAL AND SURGICAL HOSPITALS    23
# 6777             GENERAL MEDICAL AND SURGICAL HOSPITALS   541
# 6786             GENERAL MEDICAL AND SURGICAL HOSPITALS   126
# 6808             GENERAL MEDICAL AND SURGICAL HOSPITALS   733
# 6813             GENERAL MEDICAL AND SURGICAL HOSPITALS  1091

# %%
nash_hospitals = nash_hospitals.loc[nash_hospitals['STATE'] == 'TN']
nash_hospitals
# Out:
#                                                NAME  \
# 545                  TRISTAR SKYLINE MEDICAL CENTER
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                           CURAHEALTH NASHVILLE
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                     SAINT THOMAS WEST HOSPITAL
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                 VANDERBILT UNIVERSITY HOSPITAL
#
#                              ADDRESS       CITY STATE                TYPE  \
# 545              3441 DICKERSON PIKE  NASHVILLE    TN  GENERAL ACUTE CARE
# 3449    2000 HAYES STREET, SUITE 500  NASHVILLE    TN      LONG TERM CARE
# 3485  1412 COUNTY HOSPITAL ROAD, B-1  NASHVILLE    TN      LONG TERM CARE
# 5429              2221 MURPHY AVENUE  NASHVILLE    TN               WOMEN
# 5433              1818 ALBION STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6289              2000 CHURCH STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6293             2201 CHILDREN'S WAY  NASHVILLE    TN      REHABILITATION
# 6661                 1310 24TH AVE S  NASHVILLE    TN            MILITARY
# 6774              2011 MURPHY AVENUE  NASHVILLE    TN  GENERAL ACUTE CARE
# 6777               4220 HARDING ROAD  NASHVILLE    TN  GENERAL ACUTE CARE
# 6786                391 WALLACE ROAD  NASHVILLE    TN  GENERAL ACUTE CARE
# 6808           2300 PATTERSON STREET  NASHVILLE    TN  GENERAL ACUTE CARE
# 6813       1211 MEDICAL CENTER DRIVE  NASHVILLE    TN  GENERAL ACUTE CARE
#
#       POPULATION    COUNTY COUNTYFIPS  \
# 545          213  DAVIDSON      47037
# 3449          70  DAVIDSON      47037
# 3485          60  DAVIDSON      47037
# 5429        -999  DAVIDSON      47037
# 5433         150  DAVIDSON      47037
# 6289         683  DAVIDSON      47037
# 6293          80  DAVIDSON      47037
# 6661         493  DAVIDSON      47037
# 6774          23  DAVIDSON      47037
# 6777         541  DAVIDSON      47037
# 6786         126  DAVIDSON      47037
# 6808         733  DAVIDSON      47037
# 6813        1091  DAVIDSON      47037
#
#                                              NAICS_DESC  BEDS
# 545              GENERAL MEDICAL AND SURGICAL HOSPITALS   213
# 3449  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...    70
# 3485  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...    60
# 5429  SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE AB...  -999
# 5433             GENERAL MEDICAL AND SURGICAL HOSPITALS   150
# 6289             GENERAL MEDICAL AND SURGICAL HOSPITALS   683
# 6293  REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, D...    80
# 6661             GENERAL MEDICAL AND SURGICAL HOSPITALS   493
# 6774             GENERAL MEDICAL AND SURGICAL HOSPITALS    23
# 6777             GENERAL MEDICAL AND SURGICAL HOSPITALS   541
# 6786             GENERAL MEDICAL AND SURGICAL HOSPITALS   126
# 6808             GENERAL MEDICAL AND SURGICAL HOSPITALS   733
# 6813             GENERAL MEDICAL AND SURGICAL HOSPITALS  1091

# %%
nash_hospitals['NAME']
# Out:
# 545                    TRISTAR SKYLINE MEDICAL CENTER
# 3449            SELECT SPECIALTY HOSPITAL - NASHVILLE
# 3485                             CURAHEALTH NASHVILLE
# 5429               THE WOMEN'S HOSPITAL AT CENTENNIAL
# 5433          METROPOLITAN NASHVILLE GENERAL HOSPITAL
# 6289                    SAINT THOMAS MIDTOWN HOSPITAL
# 6293    VANDERBILT STALLWORTH REHABILITATION HOSPITAL
# 6661             VA MEDICAL CENTER - NASHVILLE CAMPUS
# 6774      SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY
# 6777                       SAINT THOMAS WEST HOSPITAL
# 6786            TRISTAR SOUTHERN HILLS MEDICAL CENTER
# 6808                TRISTAR CENTENNIAL MEDICAL CENTER
# 6813                   VANDERBILT UNIVERSITY HOSPITAL
# Name: NAME, dtype: object

# %%
nash_hospitals[['NAME', 'BEDS']]
# Out:
#                                                NAME  BEDS
# 545                  TRISTAR SKYLINE MEDICAL CENTER   213
# 3449          SELECT SPECIALTY HOSPITAL - NASHVILLE    70
# 3485                           CURAHEALTH NASHVILLE    60
# 5429             THE WOMEN'S HOSPITAL AT CENTENNIAL  -999
# 5433        METROPOLITAN NASHVILLE GENERAL HOSPITAL   150
# 6289                  SAINT THOMAS MIDTOWN HOSPITAL   683
# 6293  VANDERBILT STALLWORTH REHABILITATION HOSPITAL    80
# 6661           VA MEDICAL CENTER - NASHVILLE CAMPUS   493
# 6774    SAINT THOMAS HOSPITAL FOR SPECIALTY SURGERY    23
# 6777                     SAINT THOMAS WEST HOSPITAL   541
# 6786          TRISTAR SOUTHERN HILLS MEDICAL CENTER   126
# 6808              TRISTAR CENTENNIAL MEDICAL CENTER   733
# 6813                 VANDERBILT UNIVERSITY HOSPITAL  1091

# %% [markdown]
# 7. Which county in Tennessee has the most hospitals?

# %%
hospitals_tn = hospitals.loc[hospitals['STATE'] == 'TN']
hospitals_tn
# Out:
#                                           NAME                    ADDRESS  \
# 515       STARR REGIONAL MEDICAL CENTER ETOWAH      886 HIGHWAY 411 NORTH
# 535                    JACKSON COUNTY HOSPITAL         620 HOSPITAL DRIVE
# 536                    MAURY REGIONAL HOSPITAL       1224 TROTWOOD AVENUE
# 537   WEST TENNESSEE HEALTHCARE NORTH HOSPITAL         367 HOSPITAL BLVD.
# 540                HENRY COUNTY MEDICAL CENTER           301 TYSON AVENUE
# ...                                        ...                        ...
# 6810             TRISTAR PORTLAND MEDICAL PARK             105 RED BUD DR
# 6811         TRISTAR STONECREST MEDICAL CENTER   200 STONECREST BOULEVARD
# 6812           UNICOI COUNTY MEMORIAL HOSPITAL        100 GREENWAY CIRCLE
# 6813            VANDERBILT UNIVERSITY HOSPITAL  1211 MEDICAL CENTER DRIVE
# 7362                    UNICOI COUNTY HOSPITAL      2030 TEMPLE HILL ROAD
#
#             CITY STATE                TYPE  POPULATION      COUNTY COUNTYFIPS  \
# 515       ETOWAH    TN  GENERAL ACUTE CARE          72      MCMINN      47107
# 535   GAINESBORO    TN  GENERAL ACUTE CARE        -999     JACKSON      47087
# 536     COLUMBIA    TN  GENERAL ACUTE CARE         255       MAURY      47119
# 537      JACKSON    TN  GENERAL ACUTE CARE         152     MADISON      47113
# 540        PARIS    TN  GENERAL ACUTE CARE         142       HENRY      47079
# ...          ...   ...                 ...         ...         ...        ...
# 6810    PORTLAND    TN  GENERAL ACUTE CARE         159      SUMNER      47165
# 6811      SMYRNA    TN  GENERAL ACUTE CARE         109  RUTHERFORD      47149
# 6812       ERWIN    TN  GENERAL ACUTE CARE          10      UNICOI      47171
# 6813   NASHVILLE    TN  GENERAL ACUTE CARE        1091    DAVIDSON      47037
# 7362       ERWIN    TN  GENERAL ACUTE CARE          10      UNICOI      47171
#
#                                   NAICS_DESC  BEDS
# 515   GENERAL MEDICAL AND SURGICAL HOSPITALS    72
# 535   GENERAL MEDICAL AND SURGICAL HOSPITALS  -999
# 536   GENERAL MEDICAL AND SURGICAL HOSPITALS   255
# 537   GENERAL MEDICAL AND SURGICAL HOSPITALS   152
# 540   GENERAL MEDICAL AND SURGICAL HOSPITALS   142
# ...                                      ...   ...
# 6810  GENERAL MEDICAL AND SURGICAL HOSPITALS   159
# 6811  GENERAL MEDICAL AND SURGICAL HOSPITALS   109
# 6812  GENERAL MEDICAL AND SURGICAL HOSPITALS    10
# 6813  GENERAL MEDICAL AND SURGICAL HOSPITALS  1091
# 7362  GENERAL MEDICAL AND SURGICAL HOSPITALS    10
#
# [171 rows x 10 columns]

# %%
hospitals_tn
# Out:
#                                           NAME                    ADDRESS  \
# 515       STARR REGIONAL MEDICAL CENTER ETOWAH      886 HIGHWAY 411 NORTH
# 535                    JACKSON COUNTY HOSPITAL         620 HOSPITAL DRIVE
# 536                    MAURY REGIONAL HOSPITAL       1224 TROTWOOD AVENUE
# 537   WEST TENNESSEE HEALTHCARE NORTH HOSPITAL         367 HOSPITAL BLVD.
# 540                HENRY COUNTY MEDICAL CENTER           301 TYSON AVENUE
# ...                                        ...                        ...
# 6810             TRISTAR PORTLAND MEDICAL PARK             105 RED BUD DR
# 6811         TRISTAR STONECREST MEDICAL CENTER   200 STONECREST BOULEVARD
# 6812           UNICOI COUNTY MEMORIAL HOSPITAL        100 GREENWAY CIRCLE
# 6813            VANDERBILT UNIVERSITY HOSPITAL  1211 MEDICAL CENTER DRIVE
# 7362                    UNICOI COUNTY HOSPITAL      2030 TEMPLE HILL ROAD
#
#             CITY STATE                TYPE  POPULATION      COUNTY COUNTYFIPS  \
# 515       ETOWAH    TN  GENERAL ACUTE CARE          72      MCMINN      47107
# 535   GAINESBORO    TN  GENERAL ACUTE CARE        -999     JACKSON      47087
# 536     COLUMBIA    TN  GENERAL ACUTE CARE         255       MAURY      47119
# 537      JACKSON    TN  GENERAL ACUTE CARE         152     MADISON      47113
# 540        PARIS    TN  GENERAL ACUTE CARE         142       HENRY      47079
# ...          ...   ...                 ...         ...         ...        ...
# 6810    PORTLAND    TN  GENERAL ACUTE CARE         159      SUMNER      47165
# 6811      SMYRNA    TN  GENERAL ACUTE CARE         109  RUTHERFORD      47149
# 6812       ERWIN    TN  GENERAL ACUTE CARE          10      UNICOI      47171
# 6813   NASHVILLE    TN  GENERAL ACUTE CARE        1091    DAVIDSON      47037
# 7362       ERWIN    TN  GENERAL ACUTE CARE          10      UNICOI      47171
#
#                                   NAICS_DESC  BEDS
# 515   GENERAL MEDICAL AND SURGICAL HOSPITALS    72
# 535   GENERAL MEDICAL AND SURGICAL HOSPITALS  -999
# 536   GENERAL MEDICAL AND SURGICAL HOSPITALS   255
# 537   GENERAL MEDICAL AND SURGICAL HOSPITALS   152
# 540   GENERAL MEDICAL AND SURGICAL HOSPITALS   142
# ...                                      ...   ...
# 6810  GENERAL MEDICAL AND SURGICAL HOSPITALS   159
# 6811  GENERAL MEDICAL AND SURGICAL HOSPITALS   109
# 6812  GENERAL MEDICAL AND SURGICAL HOSPITALS    10
# 6813  GENERAL MEDICAL AND SURGICAL HOSPITALS  1091
# 7362  GENERAL MEDICAL AND SURGICAL HOSPITALS    10
#
# [171 rows x 10 columns]

# %%
hospitals_tn['COUNTY'].value_counts()
# Out:
# SHELBY        23
# DAVIDSON      15
# HAMILTON      13
# KNOX          11
# WASHINGTON     6
#               ..
# CARTER         1
# WARREN         1
# CLAY           1
# SMITH          1
# WAYNE          1
# Name: COUNTY, Length: 80, dtype: int64

# %% [markdown]
# 8. There are 95 counties in Tennessee. How many of them have no hospitals at all?

# %%
hospitals_tn['COUNTY'].nunique()
# Out:
# 80

# %%
sorted(hospitals_tn['COUNTY'].unique())
# Out:
# ['ANDERSON',
#  'BEDFORD',
#  'BENTON',
#  'BLEDSOE',
#  'BLOUNT',
#  'BRADLEY',
#  'CAMPBELL',
#  'CANNON',
#  'CARROLL',
#  'CARTER',
#  'CHEATHAM',
#  'CLAIBORNE',
#  'CLAY',
#  'COCKE',
#  'COFFEE',
#  'CUMBERLAND',
#  'DAVIDSON',
#  'DECATUR',
#  'DEKALB',
#  'DICKSON',
#  'DYER',
#  'FAYETTE',
#  'FENTRESS',
#  'FRANKLIN',
#  'GIBSON',
#  'GILES',
#  'GREENE',
#  'HAMBLEN',
#  'HAMILTON',
#  'HANCOCK',
#  'HARDEMAN',
#  'HARDIN',
#  'HAWKINS',
#  'HAYWOOD',
#  'HENDERSON',
#  'HENRY',
#  'HICKMAN',
#  'HOUSTON',
#  'HUMPHREYS',
#  'JACKSON',
#  'JEFFERSON',
#  'JOHNSON',
#  'KNOX',
#  'LAUDERDALE',
#  'LAWRENCE',
#  'LINCOLN',
#  'LOUDON',
#  'MACON',
#  'MADISON',
#  'MARION',
#  'MARSHALL',
#  'MAURY',
#  'MCMINN',
#  'MONROE',
#  'MONTGOMERY',
#  'OBION',
#  'OVERTON',
#  'PERRY',
#  'POLK',
#  'PUTNAM',
#  'RHEA',
#  'ROANE',
#  'ROBERTSON',
#  'RUTHERFORD',
#  'SCOTT',
#  'SEVIER',
#  'SHELBY',
#  'SMITH',
#  'SULLIVAN',
#  'SUMNER',
#  'TIPTON',
#  'TROUSDALE',
#  'UNICOI',
#  'WARREN',
#  'WASHINGTON',
#  'WAYNE',
#  'WEAKLEY',
#  'WHITE',
#  'WILLIAMSON',
#  'WILSON']
